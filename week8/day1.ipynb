# %% [markdown]
# # Welcome to a very busy Week 8 folder
#
# ## We have lots to do this week!
#
# We'll move at a faster pace than usual, particularly as you're becoming proficient LLM engineers.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Especially important this week: pull the latest</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml --prune</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Just one import to start with!!

import modal

# %% [markdown]
# # Setting up the modal tokens
#
# The first time you run this, please uncomment the next line and execute it.
# This is the same as running `modal setup` from the command line. It connects with Modal and installs your tokens.
#
# ## Debugging some common problems on Windows
#
# If this command fails in the next cell, or if any of the modal commands with the `!` fail, please try running them directly on the command line in an activated environment (without the `!`)
#
# A student on Windows mentioned that on Windows, you might also need to run this command from a command prompt in an activated environment afterwards:
# `modal token new`
# (Thank you Ed B. for that!)
#
# Another Windows student Minh N. mentioned you may need to use this approach, from an activated environment in the command line:
# `modal token set --token-id <your_token_id> --token-secret <your_token_secret>`
#
# Also, a student David S. mentioned the following:
# > In case anyone else using Windows hits this problem: Along with having to run `modal token new` from a command prompt, you have to move the generated token file. It will deploy the token file (.modal.toml) to your Windows profile folder. The virtual environment couldn't see that location (strangely, it couldn't even after I set environment variables for it and rebooted). I moved that token file to the folder I'm operating out of for the lab and it stopped throwing auth errors.
#
# And another Windows student (Robert M. - thank you!!) added another possible step:
#
#
# > I could not get modal to see my tokens (resulting in an 'auth error'), even after copying the ".modal.toml" file to the "week8" folder and restarting JupyterLab. The fix was to manually set the environment variables (the standard way). This config method is explained by modal on their [web site](https://modal.com/docs/reference/modal.config)
# ```
# import os
# os.environ["MODAL_TOKEN_ID"] = "xxx"
# os.environ["MODAL_TOKEN_SECRET"] = "yyy"
# ```
#
# Finally: I've also heard that in some situations, you might need to restart the Kernel of this jupyter notebook after running this. (Kernel menu >> Restart Kernel and Clear Outputs of All Cells).

# %%
# Remove the '# ' from the next line and run the cell, or run this command without the excalamation mark from an activated command prompt
# !modal setup

# %%
from hello import app, hello, hello_europe

# %%
with app.run():
    reply=hello.local()
reply
# Out:
# 'Hello from Taipei, Taiwan, TW!!'

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Ashburn, Virginia, US!!'

# %% [markdown]
# ## Added thanks to student Tue H.
#
# If you look in hello.py, I've added a simple function hello_europe
#
# That uses the decorator:
# `@app.function(image=image, region="eu")`
#
# See the result below! More region specific settings are [here](https://modal.com/docs/guide/region-selection)
#
# Note that it does consume marginally more credits to specify a region.

# %%
with app.run():
    reply=hello_europe.remote()
reply
# Out:
# 'Hello from Stockholm, Stockholm, SE!!'

# %% [markdown]
# # Before we move on -
#
# ## We need to set your HuggingFace Token as a secret in Modal
#
# 1. Go to modal.com, sign in and go to your dashboard
# 2. Click on Secrets in the nav bar
# 3. Create new secret, click on Hugging Face, this new secret needs to be called **hf-secret** because that's how we refer to it in the code
# 4. Fill in your HF_TOKEN where it prompts you
#
# ### And now back to business: time to work with Llama

# %%
from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Life is a mystery, everyone must stand alone, I hear")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/samfire5200/main/ap-au30DtErU69sxKgv9Wq9mJ
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount D:\development\llm_engineering\week8\llama.py
# └── 🔨 Created function generate.
# Output()
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 4 files:  25%|██▌       | 1/4 [01:01<03:04, 61.55s/it]
# Fetching 4 files:  75%|███████▌  | 3/4 [01:02<00:16, 16.40s/it]Fetching 4 files: 100%|██████████| 4/4 [01:02<00:00, 15.69s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:04<00:13,  4.55s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:09<00:09,  4.95s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:14<00:04,  4.91s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:15<00:00,  3.13s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:15<00:00,  3.76s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at https://modal.com/apps/samfire5200/main/ap-au30DtErU69sxKgv9Wq9mJ
# '<|begin_of_text|>Life is a mystery, everyone must stand alone, I hear you call my name,'

# %%
import modal
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/samfire5200/main/ap-M9dUgMVAqvRYSAOQG09n0R
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_ephemeral.py
# └── 🔨 Created function price.
# Output()
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 4 files:  25%|██▌       | 1/4 [02:07<06:22, 127.53s/it]
# Fetching 4 files: 100%|██████████| 4/4 [02:07<00:00, 31.89s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:05<00:16,  5.50s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:11<00:11,  5.98s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:17<00:05,  5.94s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:18<00:00,  3.81s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:18<00:00,  4.56s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at https://modal.com/apps/samfire5200/main/ap-M9dUgMVAqvRYSAOQG09n0R
# 25.0

# %% [markdown]
# ## Transitioning From Ephemeral Apps to Deployed Apps
#
# From a command line, `modal deploy xxx` will deploy your code as a Deployed App
#
# This is how you could package your AI service behind an API to be used in a Production System.
#
# You can also build REST endpoints easily, although we won't cover that as we'll be calling direct from Python.
#
# ## Important note for Windows people:
#
# On the next line, I call `modal deploy` from within Jupyter lab; I've heard that on some versions of Windows this gives a strange unicode error because modal prints emojis to the output which can't be displayed. If that happens to you, simply use an Anaconda Prompt window or a Powershell instead, with your environment activated, and type `modal deploy pricer_service` there. Follow the same approach the next time we do `!modal deploy` too.
#
# As an alternative, a few students have mentioned you can run this code within Jupyter Lab if you want to run it from here:
# ```
# # Check the default encoding
# print(locale.getpreferredencoding())  # Should print 'UTF-8'
#
# # Ensure UTF-8 encoding
# os.environ['PYTHONIOENCODING'] = 'utf-8'
# ```

# %%
# !modal deploy pricer_service
# Out:
# ┌─ Modal Deprecation Warning (2025-02-06) ────────────────────────────────────┐
# │ Using Python module paths will require using the -m flag in a future        │
# │ version of Modal.                                                           │
# │ Use `modal deploy -m pricer_service` instead.                               │
# └─────────────────────────────────────────────────────────────────────────────┘
# - Creating objects...
# | Creating objects...
# - Creating objects...
# | Creating objects...
# └── - Creating mount D:\development\llm_engineering\week8\pricer_service.py:
#     Uploaded 0/1 files
# - Creating objects...
# └── | Creating mount D:\development\llm_engineering\week8\pricer_service.py:
#     Uploaded 0/1 files
# | Creating objects...
# └── / Creating mount D:\development\llm_engineering\week8\pricer_service.py:
#     Finalizing index of 1 files
# - Creating objects...
# └── \ Creating mount D:\development\llm_engineering\week8\pricer_service.py:
#     Finalizing index of 1 files
# | Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service.py
# └── - Creating function price...
# - Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service.py
# └── | Creating function price...
# \ Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service.py
# └── 🔨 Created function price.
#
# ✓ Created objects.
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service.py
# └── 🔨 Created function price.
# ✓ App deployed in 4.003s! 🎉
#
# View Deployment:
# https://modal.com/apps/samfire5200/main/deployed/pricer-service

# %%
pricer = modal.Function.lookup("pricer-service", "price")
# Out:
# C:\Program Files\Python\Python310\lib\asyncio\events.py:80: DeprecationError: 2025-01-27: `modal.Function.lookup` is deprecated and will be removed in a future release. It can be replaced with `modal.Function.from_name`.
#
# See https://modal.com/docs/guide/modal-1-0-migration for more information.
#   self._context.run(self._callback, *self._args)

# %%
pricer.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 60.0

# %%
# You can also run "modal deploy -m pricer_service2" at the command line in an activated environment
# !modal deploy -m pricer_service2
# Out:
# ┌─ Modal Deprecation Warning (2025-01-15) ────────────────────────────────────┐
# │ The `@modal.build` decorator is deprecated and will be removed in a future  │
# │ release.                                                                    │
# │                                                                             │
# │ We now recommend storing large assets (such as model weights) using a       │
# │ `modal.Volume` instead of writing them directly into the `modal.Image`      │
# │ filesystem. For other use cases we recommend using `Image.run_function`     │
# │ instead.                                                                    │
# │                                                                             │
# │ See https://modal.com/docs/guide/modal-1-0-migration for more information.  │
# │                                                                             │
# │ Source: D:\development\llm_engineering\week8\pricer_service2.py:33          │
# │   @modal.build()                                                            │
# └─────────────────────────────────────────────────────────────────────────────┘
# - Creating objects...
# | Creating objects...
# / Creating objects...
# └── - Creating mount D:\development\llm_engineering\week8\pricer_service2.py:
#     Uploaded 0/1 files
# | Creating objects...
# └── | Creating mount D:\development\llm_engineering\week8\pricer_service2.py:
#     Uploaded 0/1 files
# / Creating objects...
# └── / Creating mount D:\development\llm_engineering\week8\pricer_service2.py:
#     Finalizing index of 1 files
# | Creating objects...
# └── | Creating mount D:\development\llm_engineering\week8\pricer_service2.py:
#     Finalizing index of 1 files
# - Creating objects...
# └── - Creating mount D:\development\llm_engineering\week8\pricer_service2.py:
#     Finalizing index of 1 files
# | Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service2.py
# └── - Creating function Pricer.download_model_to_folder...
# - Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service2.py
# └── | Creating function Pricer.download_model_to_folder...
# | Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── - Creating function Pricer.*...
# - Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── 🔨 Created function Pricer.*.
# | Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── 🔨 Created function Pricer.*.
# - Creating objects...
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── 🔨 Created function Pricer.*.
#
# ✓ Created objects.
# ├── 🔨 Created mount D:\development\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── 🔨 Created function Pricer.*.
# ✓ App deployed in 5.352s! 🎉
#
# View Deployment:
# https://modal.com/apps/samfire5200/main/deployed/pricer-service

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# 60.0

# %%
# !pip install --upgrade modal
# Out:
# Requirement already satisfied: modal in d:\development\llm_engineering\llme_venv\lib\site-packages (1.0.2)
# Requirement already satisfied: aiohttp in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (3.11.18)
# Requirement already satisfied: certifi in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (2025.4.26)
# Requirement already satisfied: click~=8.1.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (8.1.8)
# Requirement already satisfied: grpclib==0.4.7 in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (0.4.7)
# Requirement already satisfied: protobuf!=4.24.0,<7.0,>=3.19 in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (5.29.4)
# Requirement already satisfied: rich>=12.0.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (14.0.0)
# Requirement already satisfied: synchronicity~=0.9.12 in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (0.9.12)
# Requirement already satisfied: toml in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (0.10.2)
# Requirement already satisfied: typer>=0.9 in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (0.15.4)
# Requirement already satisfied: types-certifi in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (2021.10.8.3)
# Requirement already satisfied: types-toml in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (0.10.8.20240310)
# Requirement already satisfied: watchfiles in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (1.0.5)
# Requirement already satisfied: typing_extensions~=4.6 in d:\development\llm_engineering\llme_venv\lib\site-packages (from modal) (4.13.2)
# Requirement already satisfied: h2<5,>=3.1.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from grpclib==0.4.7->modal) (4.2.0)
# Requirement already satisfied: multidict in d:\development\llm_engineering\llme_venv\lib\site-packages (from grpclib==0.4.7->modal) (6.4.4)
# Requirement already satisfied: colorama in d:\development\llm_engineering\llme_venv\lib\site-packages (from click~=8.1.0->modal) (0.4.6)
# Requirement already satisfied: hyperframe<7,>=6.1 in d:\development\llm_engineering\llme_venv\lib\site-packages (from h2<5,>=3.1.0->grpclib==0.4.7->modal) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in d:\development\llm_engineering\llme_venv\lib\site-packages (from h2<5,>=3.1.0->grpclib==0.4.7->modal) (4.1.0)
# Requirement already satisfied: sigtools>=4.0.1 in d:\development\llm_engineering\llme_venv\lib\site-packages (from synchronicity~=0.9.12->modal) (4.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from rich>=12.0.0->modal) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from rich>=12.0.0->modal) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\development\llm_engineering\llme_venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->modal) (0.1.2)
# Requirement already satisfied: attrs in d:\development\llm_engineering\llme_venv\lib\site-packages (from sigtools>=4.0.1->synchronicity~=0.9.12->modal) (25.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from typer>=0.9->modal) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from aiohttp->modal) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\development\llm_engineering\llme_venv\lib\site-packages (from aiohttp->modal) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from aiohttp->modal) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\development\llm_engineering\llme_venv\lib\site-packages (from aiohttp->modal) (1.6.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from aiohttp->modal) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from aiohttp->modal) (1.20.0)
# Requirement already satisfied: idna>=2.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->modal) (3.10)
# Requirement already satisfied: anyio>=3.0.0 in d:\development\llm_engineering\llme_venv\lib\site-packages (from watchfiles->modal) (4.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\development\llm_engineering\llme_venv\lib\site-packages (from anyio>=3.0.0->watchfiles->modal) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\development\llm_engineering\llme_venv\lib\site-packages (from anyio>=3.0.0->watchfiles->modal) (1.3.1)

# %% [markdown]
# # Optional: Keeping Modal warm
#
# ## A way to improve the speed of the Modal pricer service
#
# A student mentioned to me that he was concerned by how slow Modal seems to be. The reason is that Modal puts our service to sleep if we don't use it, and then it takes 2.5 minutes to spin back up.
#
# I've added a utility called `keep_warm.py` that will keep our Modal warm by pinging it every 30 seconds.
#
# To use the utliity, bring up a new Terminal (Mac) or Anaconda prompt (Windows), ensure the environment is activated with `conda activate llms`
#
# Then run: `python keep_warm.py` from within the week8 drectory.
#
# Remember to press ctrl+C or exit the window when you no longer need Modal running.

# %% [markdown]
# ## And now introducing our Agent class

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
# Out:
# 299.0
