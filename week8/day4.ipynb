# %% [markdown]
# # The Price is Right
#
# First we'll polish off 2 more simple agents:
#
# The **Messaging Agent** to send push notifications
#
# The **Planning Agent** to coordinate activities
#
# Then we'll put it all together into an Agent Framework.
#
# - For the Push Notification, we will be using a nifty platform called Pushover https://pushover.net/.
# - You'll need to set up a free account and add 2 tokens to your `.env` file:
#     - https://pushover.net for 'PUSHOVER_USER'
#     - https://pushover.net/apps/build for 'PUSHOVER_TOKEN'
#
# ```
# PUSHOVER_USER=xxx
# PUSHOVER_TOKEN=xxx
# ```

# %%
from dotenv import load_dotenv
from agents.messaging_agent import MessagingAgent

import nest_asyncio

# %%
load_dotenv(override=True)
DB = "products_vectorstore"

nest_asyncio.apply()

# %%
agent = MessagingAgent()

# %%
agent.push("MASSIVE NEWS!!!")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Additional resource: more sophisticated planning agent</h2>
#             <span style="color:#f71;">The Planning Agent that we use in the next cell is simply a python script that calls the other Agents; frankly that's all we require for this project. But if you're intrigued to see a more Autonomous version in which we give the Planning Agent tools and allow it to decide which Agents to call, see my implementation of <a href="https://github.com/ed-donner/agentic/blob/main/workshop/agents/autonomous_planning_agent.py">AutonomousPlanningAgent</a> in my related repo, <a href="https://github.com/ed-donner/agentic">Agentic</a>. This is an example with multiple tools that dynamically decides which function to call.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import chromadb
DB = "products_vectorstore"
client = chromadb.PersistentClient(path=DB)
collection = client.get_or_create_collection('products')
from agents.planning_agent import PlanningAgent

# %%
planner = PlanningAgent(collection)

# %%
planner.plan()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<?, ?it/s]
# Opportunity(deal=Deal(product_description='The certified refurbished iRobot Roomba j7+ is a self-emptying robot vacuum that cleverly maps your home for efficient cleaning. Equipped with smart mapping technology, it learns your layout to navigate effectively. This model features a self-cleaning cartridge filter which reduces maintenance, allowing you to enjoy the benefits of a cleaner home without the hassle. It includes a 2-year Allstate warranty, ensuring reliability in your purchase.', price=175.0, url='https://www.dealnews.com/products/iRobot/iRobot-Roomba-j7-Self-Emptying-Robot-Vacuum/455442.html?iref=rss-f1912'), estimate=490.6607534191433, discount=315.6607534191433)

# %%
# !py test_planner.py
# Out:
# Get collection 'products'.
# Created planningAgent, please wait...
# Planning completed with result: deal=Deal(product_description="The Unlocked Google Pixel Fold is a 256GB Android smartphone that boasts a stunning foldable design, making multitasking and media consumption a breeze. With its high-resolution display, superior camera capabilities, and impressive battery life, this phone is engineered for those who demand productivity and performance. Ideal for capturing photos and videos, it integrates seamlessly with Google's ecosystem, providing exclusive features and updates, ensuring a leading-edge user experience.", price=600.0, url='https://www.dealnews.com/products/Google/Unlocked-Google-Pixel-Fold-256-GB-Android-Smartphone/467718.html?iref=rss-c142') estimate=904.2631911890497 discount=304.26319118904973.
#   0%|          | 0/9 [00:00<?, ?it/s]
# 100%|██████████| 9/9 [00:00<?, ?it/s]

# %%
from deal_agent_framework import DealAgentFramework

# %%
framework = DealAgentFramework()
results = framework.run()
# Out:
# INFO:root:[Agent Framework] Initializing Agent Framework
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# INFO:root:[Planning Agent] Planning Agent is initializing
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# INFO:root:[Scanner Agent] Scanner Agent is initializing
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# INFO:root:[Scanner Agent] Scanner Agent is ready
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# INFO:root:[Ensemble Agent] Initializing Ensemble Agent
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# INFO:root:[Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# INFO:root:[Specialist Agent] Specialist Agent is ready
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# INFO:root:[Frontier Agent] Initializing Frontier Agent
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# INFO:root:[Frontier Agent] Frontier Agent is set up with DeepSeek
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is set up with DeepSeek
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cpu
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] Use pytorch device_name: cpu
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-06-09 16:04:00 +0800] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# INFO:root:[Frontier Agent] Frontier Agent is ready
# [2025-06-09 16:04:03 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# INFO:root:[Random Forest Agent] Random Forest Agent is initializing
# [2025-06-09 16:04:03 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cpu
# [2025-06-09 16:04:03 +0800] [Agents] [INFO] Use pytorch device_name: cpu
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-06-09 16:04:03 +0800] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# INFO:root:[Random Forest Agent] Random Forest Agent is ready
# [2025-06-09 16:04:06 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# INFO:root:[Ensemble Agent] Ensemble Agent is ready
# [2025-06-09 16:04:06 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# INFO:root:[Messaging Agent] Messaging Agent is initializing
# [2025-06-09 16:04:06 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# INFO:root:[Messaging Agent] Messaging Agent has initialized Pushover
# [2025-06-09 16:04:06 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# INFO:root:[Planning Agent] Planning Agent is ready
# [2025-06-09 16:04:06 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# INFO:root:[Agent Framework] Agent Framework is ready
# [2025-06-09 16:04:06 +0800] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# INFO:root:Kicking off Planning Agent
# [2025-06-09 16:04:06 +0800] [Agents] [INFO] Kicking off Planning Agent
# INFO:root:[Planning Agent] Planning Agent is kicking off a run
# [2025-06-09 16:04:06 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# INFO:root:[Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2025-06-09 16:04:06 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<?, ?it/s]
# INFO:root:[Scanner Agent] Scanner Agent received 85 deals not already scraped
# [2025-06-09 16:04:10 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent received 85 deals not already scraped
# INFO:root:[Scanner Agent] Number of deals fetched 85
# [2025-06-09 16:04:10 +0800] [Agents] [INFO] [Scanner Agent] Number of deals fetched 85
# INFO:root:[Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# [2025-06-09 16:04:10 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-06-09 16:04:29 +0800] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2025-06-09 16:04:29 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# INFO:root:[Planning Agent] Planning Agent is pricing up a potential deal
# [2025-06-09 16:04:29 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# INFO:root:[Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-06-09 16:04:29 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-06-09 16:04:29 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $60.00
# [2025-06-09 16:04:33 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# INFO:root:[Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-06-09 16:04:33 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Frontier Agent] Frontier Agent has found similar products
# [2025-06-09 16:04:33 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# INFO:root:[Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-06-09 16:04:33 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-06-09 16:04:33 +0800] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Frontier Agent] Frontier Agent completed - predicting $49.99
# [2025-06-09 16:04:37 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $49.99
# INFO:root:[Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-06-09 16:04:37 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Random Forest Agent] Random Forest Agent completed - predicting $64.49
# [2025-06-09 16:04:38 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $64.49
# INFO:root:[Ensemble Agent] Ensemble Agent complete - returning $82.79
# [2025-06-09 16:04:38 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $82.79
# INFO:root:[Planning Agent] Planning Agent has processed a deal with discount $42.79
# [2025-06-09 16:04:38 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $42.79
# INFO:root:[Planning Agent] Planning Agent is pricing up a potential deal
# [2025-06-09 16:04:38 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# INFO:root:[Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-06-09 16:04:38 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-06-09 16:04:38 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $700.00
# [2025-06-09 16:04:40 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $700.00
# INFO:root:[Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-06-09 16:04:40 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Frontier Agent] Frontier Agent has found similar products
# [2025-06-09 16:04:40 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# INFO:root:[Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-06-09 16:04:40 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-06-09 16:04:40 +0800] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Frontier Agent] Frontier Agent completed - predicting $1099.00
# [2025-06-09 16:04:44 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $1099.00
# INFO:root:[Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-06-09 16:04:44 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Random Forest Agent] Random Forest Agent completed - predicting $111.32
# [2025-06-09 16:04:44 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $111.32
# INFO:root:[Ensemble Agent] Ensemble Agent complete - returning $877.38
# [2025-06-09 16:04:44 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $877.38
# INFO:root:[Planning Agent] Planning Agent has processed a deal with discount $-122.62
# [2025-06-09 16:04:44 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-122.62
# INFO:root:[Planning Agent] Planning Agent is pricing up a potential deal
# [2025-06-09 16:04:44 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# INFO:root:[Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-06-09 16:04:44 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-06-09 16:04:44 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $299.00
# [2025-06-09 16:04:46 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $299.00
# INFO:root:[Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-06-09 16:04:46 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Frontier Agent] Frontier Agent has found similar products
# [2025-06-09 16:04:46 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# INFO:root:[Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-06-09 16:04:46 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-06-09 16:04:46 +0800] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Frontier Agent] Frontier Agent completed - predicting $429.99
# [2025-06-09 16:04:51 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $429.99
# INFO:root:[Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-06-09 16:04:51 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Random Forest Agent] Random Forest Agent completed - predicting $128.10
# [2025-06-09 16:04:51 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $128.10
# INFO:root:[Ensemble Agent] Ensemble Agent complete - returning $399.30
# [2025-06-09 16:04:51 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $399.30
# INFO:root:[Planning Agent] Planning Agent has processed a deal with discount $99.30
# [2025-06-09 16:04:51 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $99.30
# INFO:root:[Planning Agent] Planning Agent is pricing up a potential deal
# [2025-06-09 16:04:51 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# INFO:root:[Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-06-09 16:04:51 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-06-09 16:04:51 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $799.00
# [2025-06-09 16:04:53 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $799.00
# INFO:root:[Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-06-09 16:04:53 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Frontier Agent] Frontier Agent has found similar products
# [2025-06-09 16:04:53 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# INFO:root:[Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-06-09 16:04:53 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-06-09 16:04:54 +0800] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Frontier Agent] Frontier Agent completed - predicting $799.99
# [2025-06-09 16:04:57 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $799.99
# INFO:root:[Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-06-09 16:04:57 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Random Forest Agent] Random Forest Agent completed - predicting $45.54
# [2025-06-09 16:04:57 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $45.54
# INFO:root:[Ensemble Agent] Ensemble Agent complete - returning $913.63
# [2025-06-09 16:04:57 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $913.63
# INFO:root:[Planning Agent] Planning Agent has processed a deal with discount $64.63
# [2025-06-09 16:04:57 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $64.63
# INFO:root:[Planning Agent] Planning Agent is pricing up a potential deal
# [2025-06-09 16:04:57 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# INFO:root:[Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-06-09 16:04:57 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-06-09 16:04:57 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $220.00
# [2025-06-09 16:04:59 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $220.00
# INFO:root:[Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-06-09 16:04:59 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Frontier Agent] Frontier Agent has found similar products
# [2025-06-09 16:04:59 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# INFO:root:[Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-06-09 16:04:59 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-06-09 16:05:00 +0800] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Frontier Agent] Frontier Agent completed - predicting $129.99
# [2025-06-09 16:05:03 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $129.99
# INFO:root:[Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-06-09 16:05:04 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:[Random Forest Agent] Random Forest Agent completed - predicting $61.38
# [2025-06-09 16:05:04 +0800] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $61.38
# INFO:root:[Ensemble Agent] Ensemble Agent complete - returning $117.92
# [2025-06-09 16:05:04 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $117.92
# INFO:root:[Planning Agent] Planning Agent has processed a deal with discount $37.92
# [2025-06-09 16:05:04 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $37.92
# INFO:root:[Planning Agent] Planning Agent has identified the best deal has discount $99.30
# [2025-06-09 16:05:04 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $99.30
# INFO:root:[Messaging Agent] Messaging Agent is sending a push notification
# [2025-06-09 16:05:04 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# INFO:root:[Messaging Agent] Messaging Agent has completed
# [2025-06-09 16:05:04 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# INFO:root:[Planning Agent] Planning Agent has completed a run
# [2025-06-09 16:05:04 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# INFO:root:Planning Agent has completed and returned: deal=Deal(product_description='The XFX Swift AMD Radeon RX 9060XT OC Gaming Edition Graphics Card is engineered for gaming enthusiasts who demand high performance. It comes with 8GB of video memory, providing the power needed to handle the latest games at high settings and resolutions. The card is designed for optimal thermal performance, featuring advanced cooling technology to maintain peak performance during intensive gaming sessions. Its sleek design is not only functional but also visually appealing for any gaming setup.', price=300.0, url='https://www.dealnews.com/products/XFX/XFX-Swift-AMD-Radeon-RX-9060-XT-OC-Gaming-Edition-8-GB-Graphics-Card/490359.html?iref=rss-c39') estimate=399.2970950177093 discount=99.2970950177093
# [2025-06-09 16:05:04 +0800] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='The XFX Swift AMD Radeon RX 9060XT OC Gaming Edition Graphics Card is engineered for gaming enthusiasts who demand high performance. It comes with 8GB of video memory, providing the power needed to handle the latest games at high settings and resolutions. The card is designed for optimal thermal performance, featuring advanced cooling technology to maintain peak performance during intensive gaming sessions. Its sleek design is not only functional but also visually appealing for any gaming setup.', price=300.0, url='https://www.dealnews.com/products/XFX/XFX-Swift-AMD-Radeon-RX-9060-XT-OC-Gaming-Edition-8-GB-Graphics-Card/490359.html?iref=rss-c39') estimate=399.2970950177093 discount=99.2970950177093
